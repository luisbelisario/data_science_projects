# %%
import matplotlib.pyplot as plt
import statistics as sts
# %matplotlib inline

# %%
inteligencia_artificial = [76, 82.5, 88.9, 68.2, 76, 86.5, 91.3, 98.8, 65.6, 
                           70.6, 97.3, 99.5,86, 94, 98.5, 99.8, 92, 94.3, 
                           96.9957, 96.72, 99.41,97.7, 97, 96.7, 100, 83.25, 
                           92.3, 96.97, 93.98, 96.8]

# %%
len(inteligencia_artificial)
# Out:
# 30

# %%
medicos_humanos = [62, 71.3, 75.7, 64.4, 66.5, 74.1, 75.4, 89.2, 37.1, 81.6]

# %%
plt.hist(IA, 3, rwidth=0.9)
plt.ylim(0, 25)
plt.xlim(10, 100)
plt.title('Histograma de porcentagens da Inteligência Artificial', fontsize=16)
plt.ylabel('Quantidade de diagnósticos', fontsize=13)
plt.xlabel('Porcentagem', fontsize=13)
plt.grid()
plt.show()

# %%
plt.hist(humanos, 3, rwidth=0.9)
plt.ylim(0, 25)
plt.xlim(10, 100)
plt.title('Histograma de porcentagens de Médicos Humanos', fontsize=16)
plt.ylabel('Quantidade de diagnósticos', fontsize=13)
plt.xlabel('Porcentagem', fontsize=13)
plt.grid()
plt.show()

# %%
media_inteligencia_artificial = sts.mean(IA)
media_inteligencia_artificial
# Out:
# 90.45419

# %%
media_medicos_humanos = sts.mean(humanos)
media_medicos_humanos
# Out:
# 69.73

# %%
max(inteligencia_artificial)
# Out:
# 100

# %%
max(medicos_humanos)
# Out:
# 89.2

# %%
desv_pad_inteligencia_artificial = sts.stdev(IA)
desv_pad_inteligencia_artificial
# Out:
# 10.077751976006184

# %%
desv_pad_medicos_humanos = sts.stdev(humanos)
desv_pad_medicos_humanos
# Out:
# 14.034247792849857
